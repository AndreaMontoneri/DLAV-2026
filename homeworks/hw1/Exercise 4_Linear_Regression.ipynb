# %% [markdown]
# # Intro to Python: Exercise 4

# %% [markdown]
# ## Linear regression with one variable

# %% [markdown]
# In the first part of the exercise, we're tasked with implementing linear regression with one variable to predict profits for a food truck. Suppose you are the CEO of a restaurant franchise and are considering different cities for opening a new outlet. The chain already has trucks in various cities and you have data for profits and populations from the cities.

# %% [markdown]
# Let's start by importing some libraries and examining the data.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import os

# %% [markdown]
# Read the data from the CSV file using Panda library

# %%
#!git clone https://github.com/vita-epfl/DLAV-2025.git
path = os.getcwd() + '/data/ex1data1.txt'
data = pd.read_csv(path, header=None, names=['Population', 'Profit'])
data.head()
# Out:
#    Population   Profit
# 0      6.1101  17.5920
# 1      5.5277   9.1302
# 2      8.5186  13.6620
# 3      7.0032  11.8540
# 4      5.8598   6.8233

# %%
data.describe()
# Out:
#        Population     Profit
# count   97.000000  97.000000
# mean     8.159800   5.839135
# std      3.869884   5.510262
# min      5.026900  -2.680700
# 25%      5.707700   1.986900
# 50%      6.589400   4.562300
# 75%      8.578100   7.046700
# max     22.203000  24.147000

# %% [markdown]
# Let's plot it to get a better idea of what the data looks like.

# %%
data.plot(kind='scatter', x='Population', y='Profit', figsize=(12,8))
plt.grid()
plt.show()

# %% [markdown]
# Now let's implement linear regression using gradient descent to minimize the cost function.  The equations implemented in the following code samples are detailed in "ex1.pdf" in the "exercises" folder.

# %% [markdown]
# First we'll create a function to compute the cost of a given solution (characterized by the parameters theta). The cost function is the Mean Sqaured error in matrix form:
#
# $$ MSE(\theta) = \frac{1}{N}\sum_n^N [ y_n-x_n^T*\theta]^2 $$
#
# where $\theta$ and $x_n$ are vectors
#
# __Hint__: Use the matrix form of the cost function and make use of numpy operations.

# %%
def computeCost(x, y, theta):
    # Compute the cost function
    error = (y - x @ theta)**2
    return np.mean(error)

# %% [markdown]
# Let's add a column of ones to the training set so we can use a vectorized solution to computing the cost and gradients.

# %%
data.insert(0, 'Ones', 1)

# %% [markdown]
# Now let's do some variable initialization.

# %%
# set X (training data) and y (target variable)
cols = data.shape[1]
X = data.iloc[:,0:cols-1]
y = data.iloc[:,cols-1:cols]

# %% [markdown]
# Let's take a look to make sure X (training set) and y (target variable) look correct.

# %%
X.head()
# Out:
#    Ones  Population
# 0     1      6.1101
# 1     1      5.5277
# 2     1      8.5186
# 3     1      7.0032
# 4     1      5.8598

# %%
y.head()
# Out:
#     Profit
# 0  17.5920
# 1   9.1302
# 2  13.6620
# 3  11.8540
# 4   6.8233

# %% [markdown]
# Convert X and Y to numpy array for better manipulation. Initiliaze Theta.

# %%
X = np.array(X.values)
y = np.array(y.values).flatten()
theta = np.array([0,0])
print(theta)
# Out:
# [0 0]

# %% [markdown]
# Let's take a quick look at the shape of our matrices.

# %%
X.shape, theta.shape, y.shape
# Out:
# ((97, 2), (2,), (97,))

# %% [markdown]
# Now let's compute the cost for our initial solution (0 values for theta).

# %%
print(computeCost(X, y, theta))
# Out:
# 64.14546775491135

# %% [markdown]
# So far so good.  Now we need to define a function to perform gradient descent on the parameters theta using the update rules. Write first a function that computes the gradient of a matrix and then use it in the gradientDescent function.
#
# The gradient descent formula is:
#
# $$\theta^{t+1} = \theta^{t} - \alpha*\nabla MSE(\theta^{t})$$
#
# where $\nabla MSE(\theta^{t})$ is the gradient of the cost function at $\theta^{t}$
#
# __Hint__: Use the matrix form of the gradient and make use of numpy operations.

# %%
def compute_gradient(y, tx, w):
    """Compute the gradient."""
    # ***************************************************
    # INSERT YOUR CODE HERE
    # TODO: compute gradient and loss
    # ***************************************************
    N = tx.shape[0]
    error = y - tx @ w
    grad = (-1/N) * (tx.T @ error)
    return grad

# %%
def gradientDescent(X, y, theta, alpha, max_iters):
    """Gradient descent algorithm."""
    # Define parameters to store w and loss
    ws = [theta]
    cost = np.zeros(max_iters)
    for n_iter in range(max_iters):
        # ***************************************************
        # INSERT YOUR CODE HERE
        # TODO: compute gradient and loss
        # ***************************************************
        loss = computeCost(X, y, theta)
        grad_i = compute_gradient(y, X, theta)
        # ***************************************************
        # INSERT YOUR CODE HERE
        # TODO: update theta by gradient
        # ***************************************************
        theta = theta - alpha * grad_i
        # store w and loss
        ws.append(theta)
        cost[n_iter] = loss
        print("Gradient Descent({bi}/{ti}): loss={l}, w0={w0}, w1={w1}".format(
              bi=n_iter, ti=max_iters - 1, l=loss, w0=theta[0], w1=theta[1]))

    return theta, cost

# %% [markdown]
# Initialize some additional variables - the learning rate alpha, and the number of iterations to perform.

# %%
alpha = 0.01
iters = 1000

# %% [markdown]
# Now let's run the gradient descent algorithm to fit our parameters theta to the training set.

# %%
g, cost = gradientDescent(X, y, theta, alpha, iters)
print(g)
# Out:
# Gradient Descent(0/999): loss=64.14546775491135, w0=0.058391350515463916, w1=0.6532884974555669
# Gradient Descent(1/999): loss=13.474380929740022, w0=0.06289175271039385, w1=0.7700097825599364
# Gradient Descent(2/999): loss=11.863187137209913, w0=0.05782292746142814, w1=0.7913481156584673
# Gradient Descent(3/999): loss=11.802309414162776, w0=0.05106362516077816, w1=0.795729810284954
# Gradient Descent(4/999): loss=11.790457172888441, w0=0.04401437836500262, w1=0.7970961782721866
# Gradient Descent(5/999): loss=11.78018988623466, w0=0.03692413114216263, w1=0.7979254732843951
# Gradient Descent(6/999): loss=11.770008316887292, w0=0.02983711757714485, w1=0.7986582394519285
# Gradient Descent(7/999): loss=11.759864960982835, w0=0.02276118189403886, w1=0.7993727912003019
# Gradient Descent(8/999): loss=11.74975818952515, w0=0.01569769957420015, w1=0.8000830518518655
# Gradient Descent(9/999): loss=11.739687823612776, w0=0.008646896228913549, w1=0.8007914983590768
# Gradient Descent(10/999): loss=11.729653730625861, w0=0.0016087930989843804, w1=0.8014985729280016
# Gradient Descent(11/999): loss=11.719655779864363, w0=-0.005416624870320623, w1=0.8022043560583255
# Gradient Descent(12/999): loss=11.70969384114458, w0=-0.012429379151800745, w1=0.8029088639482521
# Gradient Descent(13/999): loss=11.699767784753174, w0=-0.019429492325268298, w1=0.8036121013621462
# Gradient Descent(14/999): loss=11.689877481444068, w0=-0.026416987133500103, w1=0.8043140710284592
# Gradient Descent(15/999): loss=11.680022802436723, w0=-0.033391886314481395, w1=0.8050147753103406
# Gradient Descent(16/999): loss=11.670203619414451, w0=-0.040354212571645835, w1=0.8057142165026173
# Gradient Descent(17/999): loss=11.660419804522776, w0=-0.047303988568646024, w1=0.8064123968845912
# Gradient Descent(18/999): loss=11.650671230367724, w0=-0.05424123692848452, w1=0.8071093187294315
# Gradient Descent(19/999): loss=11.640957770014198, w0=-0.0611659802334199, w1=0.8078049843058496
# Gradient Descent(20/999): loss=11.631279296984308, w0=-0.0680782410250105, w1=0.8084993958784037
# Gradient Descent(21/999): loss=11.621635685255738, w0=-0.07497804180418247, w1=0.8091925557075582
# Gradient Descent(22/999): loss=11.612026809260088, w0=-0.08186540503130206, w1=0.8098844660497012
# Gradient Descent(23/999): loss=11.602452543881256, w0=-0.08874035312624864, w1=0.8105751291571527
# Gradient Descent(24/999): loss=11.5929127644538, w0=-0.09560290846848758, w1=0.8112645472781728
# Gradient Descent(25/999): loss=11.583407346761305, w0=-0.10245309339714313, w1=0.8119527226569687
# Gradient Descent(26/999): loss=11.573936167034791, w0=-0.10929093021107111, w1=0.8126396575337025
# Gradient Descent(27/999): loss=11.564499101951078, w0=-0.11611644116893154, w1=0.813325354144498
# Gradient Descent(28/999): loss=11.555096028631192, w0=-0.12292964848926105, w1=0.8140098147214483
# Gradient Descent(29/999): loss=11.545726824638765, w0=-0.12973057435054525, w1=0.8146930414926226
# Gradient Descent(30/999): loss=11.536391367978428, w0=-0.1365192408912909, w1=0.8153750366820742
# Gradient Descent(31/999): loss=11.52708953709424, w0=-0.14329567021009795, w1=0.8160558025098472
# Gradient Descent(32/999): loss=11.517821210868098, w0=-0.15005988436573156, w1=0.8167353411919838
# Gradient Descent(33/999): loss=11.508586268618155, w0=-0.1568119053771938, w1=0.8174136549405314
# Gradient Descent(34/999): loss=11.499384590097257, w0=-0.16355175522379542, w1=0.8180907459635505
# Gradient Descent(35/999): loss=11.490216055491368, w0=-0.17027945584522733, w1=0.8187666164651208
# Gradient Descent(36/999): loss=11.481080545418022, w0=-0.17699502914163207, w1=0.8194412686453493
# Gradient Descent(37/999): loss=11.471977940924763, w0=-0.18369849697367505, w1=0.8201147047003767
# Gradient Descent(38/999): loss=11.462908123487583, w0=-0.1903898811626157, w1=0.8207869268223855
# Gradient Descent(39/999): loss=11.453870975009403, w0=-0.19706920349037865, w1=0.8214579371996062
# Gradient Descent(40/999): loss=11.44486637781851, w0=-0.2037364856996244, w1=0.8221277380163249
# Gradient Descent(41/999): loss=11.435894214667057, w0=-0.21039174949382033, w1=0.8227963314528902
# Gradient Descent(42/999): loss=11.426954368729499, w0=-0.21703501653731114, w1=0.8234637196857207
# Gradient Descent(43/999): loss=11.418046723601098, w0=-0.22366630845538954, w1=0.8241299048873114
# Gradient Descent(44/999): loss=11.409171163296397, w0=-0.23028564683436656, w1=0.8247948892262416
# Gradient Descent(45/999): loss=11.400327572247711, w0=-0.23689305322164184, w1=0.825458674867181
# Gradient Descent(46/999): loss=11.391515835303629, w0=-0.24348854912577375, w1=0.826121263970898
# Gradient Descent(47/999): loss=11.382735837727502, w0=-0.2500721560165494, w1=0.8267826586942654
# Gradient Descent(48/999): loss=11.37398746519596, w0=-0.25664389532505466, w1=0.8274428611902682
# Gradient Descent(49/999): loss=11.365270603797414, w0=-0.2632037884437437, w1=0.8281018736080105
# Gradient Descent(50/999): loss=11.356585140030584, w0=-0.2697518567265088, w1=0.8287596980927223
# Gradient Descent(51/999): loss=11.34793096080301, w0=-0.27628812148874976, w1=0.8294163367857669
# Gradient Descent(52/999): loss=11.339307953429593, w0=-0.28281260400744335, w1=0.8300717918246472
# Gradient Descent(53/999): loss=11.330716005631107, w0=-0.28932532552121254, w1=0.8307260653430134
# Gradient Descent(54/999): loss=11.322155005532757, w0=-0.2958263072303957, w1=0.8313791594706694
# Gradient Descent(55/999): loss=11.313624841662717, w0=-0.30231557029711553, w1=0.8320310763335801
# Gradient Descent(56/999): loss=11.305125402950667, w0=-0.30879313584534795, w1=0.8326818180538778
# Gradient Descent(57/999): loss=11.296656578726362, w0=-0.3152590249609909, w1=0.8333313867498697
# Gradient Descent(58/999): loss=11.288218258718183, w0=-0.32171325869193296, w1=0.8339797845360446
# Gradient Descent(59/999): loss=11.279810333051707, w0=-0.32815585804812186, w1=0.8346270135230796
# Gradient Descent(60/999): loss=11.27143269224827, w0=-0.33458684400163297, w1=0.835273075817847
# Gradient Descent(61/999): loss=11.263085227223543, w0=-0.3410062374867374, w1=0.8359179735234217
# Gradient Descent(62/999): loss=11.25476782928611, w0=-0.3474140593999703, w1=0.8365617087390871
# Gradient Descent(63/999): loss=11.246480390136053, w0=-0.3538103306001987, w1=0.8372042835603428
# Gradient Descent(64/999): loss=11.238222801863555, w0=-0.3601950719086896, w1=0.8378457000789108
# Gradient Descent(65/999): loss=11.22999495694748, w0=-0.36656830410917773, w1=0.8384859603827426
# Gradient Descent(66/999): loss=11.22179674825397, w0=-0.37293004794793305, w1=0.8391250665560263
# Gradient Descent(67/999): loss=11.213628069035062, w0=-0.37928032413382845, w1=0.8397630206791926
# Gradient Descent(68/999): loss=11.205488812927296, w0=-0.385619153338407, w1=0.8403998248289224
# Gradient Descent(69/999): loss=11.197378873950319, w0=-0.3919465561959494, w1=0.8410354810781527
# Gradient Descent(70/999): loss=11.18929814650552, w0=-0.3982625533035411, w1=0.8416699914960845
# Gradient Descent(71/999): loss=11.181246525374647, w0=-0.4045671652211393, w1=0.8423033581481884
# Gradient Descent(72/999): loss=11.17322390571843, w0=-0.41086041247163985, w1=0.8429355830962117
# Gradient Descent(73/999): loss=11.165230183075247, w0=-0.4171423155409442, w1=0.8435666683981857
# Gradient Descent(74/999): loss=11.157265253359707, w0=-0.423412894878026, w1=0.8441966161084314
# Gradient Descent(75/999): loss=11.149329012861354, w0=-0.42967217089499765, w1=0.844825428277567
# Gradient Descent(76/999): loss=11.141421358243287, w0=-0.43592016396717664, w1=0.8454531069525142
# Gradient Descent(77/999): loss=11.133542186540808, w0=-0.4421568944331522, w1=0.8460796541765048
# Gradient Descent(78/999): loss=11.125691395160102, w0=-0.4483823825948512, w1=0.8467050719890875
# Gradient Descent(79/999): loss=11.117868881876884, w0=-0.4545966487176043, w1=0.8473293624261348
# Gradient Descent(80/999): loss=11.110074544835086, w0=-0.4607997130302121, w1=0.8479525275198488
# Gradient Descent(81/999): loss=11.102308282545504, w0=-0.4669915957250107, w1=0.8485745692987691
# Gradient Descent(82/999): loss=11.094569993884512, w0=-0.47317231695793766, w1=0.8491954897877779
# Gradient Descent(83/999): loss=11.086859578092703, w0=-0.47934189684859746, w1=0.8498152910081078
# Gradient Descent(84/999): loss=11.079176934773615, w0=-0.48550035548032716, w1=0.8504339749773481
# Gradient Descent(85/999): loss=11.071521963892408, w0=-0.4916477129002616, w1=0.8510515437094506
# Gradient Descent(86/999): loss=11.06389456577455, w0=-0.4977839891193988, w1=0.8516679992147372
# Gradient Descent(87/999): loss=11.056294641104543, w0=-0.503909204112665, w1=0.8522833434999061
# Gradient Descent(88/999): loss=11.048722090924612, w0=-0.5100233778189798, w1=0.8528975785680377
# Gradient Descent(89/999): loss=11.041176816633426, w0=-0.5161265301413208, w1=0.8535107064186023
# Gradient Descent(90/999): loss=11.033658719984805, w0=-0.5222186809467888, w1=0.8541227290474656
# Gradient Descent(91/999): loss=11.02616770308645, w0=-0.5282998500666721, w1=0.8547336484468955
# Gradient Descent(92/999): loss=11.018703668398663, w0=-0.5343700572965112, w1=0.8553434666055688
# Gradient Descent(93/999): loss=11.011266518733077, w0=-0.5404293223961634, w1=0.8559521855085775
# Gradient Descent(94/999): loss=11.003856157251398, w0=-0.5464776650898667, w1=0.8565598071374354
# Gradient Descent(95/999): loss=10.99647248746413, w0=-0.5525151050663046, w1=0.8571663334700841
# Gradient Descent(96/999): loss=10.989115413229326, w0=-0.5585416619786696, w1=0.8577717664809001
# Gradient Descent(97/999): loss=10.981784838751354, w0=-0.5645573554447275, w1=0.8583761081407008
# Gradient Descent(98/999): loss=10.974480668579613, w0=-0.5705622050468813, w1=0.8589793604167507
# Gradient Descent(99/999): loss=10.967202807607304, w0=-0.5765562303322346, w1=0.8595815252727688
# Gradient Descent(100/999): loss=10.959951161070226, w0=-0.5825394508126557, w1=0.8601826046689336
# Gradient Descent(101/999): loss=10.952725634545482, w0=-0.5885118859648408, w1=0.8607826005618906
# Gradient Descent(102/999): loss=10.945526133950302, w0=-0.5944735552303777, w1=0.8613815149047582
# Gradient Descent(103/999): loss=10.938352565540796, w0=-0.6004244780158084, w1=0.861979349647134
# Gradient Descent(104/999): loss=10.931204835910716, w0=-0.6063646736926933, w1=0.8625761067351013
# Gradient Descent(105/999): loss=10.924082851990276, w0=-0.6122941615976732, w1=0.8631717881112356
# Gradient Descent(106/999): loss=10.916986521044917, w0=-0.6182129610325332, w1=0.8637663957146104
# Gradient Descent(107/999): loss=10.909915750674093, w0=-0.6241210912642647, w1=0.864359931480804
# Gradient Descent(108/999): loss=10.902870448810102, w0=-0.6300185715251289, w1=0.8649523973419058
# Gradient Descent(109/999): loss=10.895850523716849, w0=-0.6359054210127185, w1=0.865543795226522
# Gradient Descent(110/999): loss=10.888855883988667, w0=-0.6417816588900211, w1=0.8661341270597827
# Gradient Descent(111/999): loss=10.88188643854913, w0=-0.6476473042854811, w1=0.8667233947633476
# Gradient Descent(112/999): loss=10.874942096649868, w0=-0.6535023762930621, w1=0.8673116002554123
# Gradient Descent(113/999): loss=10.868022767869373, w0=-0.6593468939723086, w1=0.8678987454507151
# Gradient Descent(114/999): loss=10.861128362111838, w0=-0.6651808763484091, w1=0.8684848322605423
# Gradient Descent(115/999): loss=10.85425878960597, w0=-0.6710043424122568, w1=0.8690698625927351
# Gradient Descent(116/999): loss=10.847413960903838, w0=-0.6768173111205124, w1=0.8696538383516959
# Gradient Descent(117/999): loss=10.840593786879673, w0=-0.682619801395665, w1=0.8702367614383937
# Gradient Descent(118/999): loss=10.833798178728763, w0=-0.6884118321260945, w1=0.8708186337503714
# Gradient Descent(119/999): loss=10.827027047966245, w0=-0.6941934221661324, w1=0.8713994571817508
# Gradient Descent(120/999): loss=10.820280306425973, w0=-0.6999645903361237, w1=0.87197923362324
# Gradient Descent(121/999): loss=10.813557866259387, w0=-0.7057253554224877, w1=0.8725579649621386
# Gradient Descent(122/999): loss=10.80685963993433, w0=-0.7114757361777795, w1=0.8731356530823439
# Gradient Descent(123/999): loss=10.80018554023395, w0=-0.7172157513207509, w1=0.8737122998643577
# Gradient Descent(124/999): loss=10.793535480255535, w0=-0.7229454195364113, w1=0.8742879071852919
# Gradient Descent(125/999): loss=10.786909373409394, w0=-0.7286647594760888, w1=0.8748624769188748
# Gradient Descent(126/999): loss=10.780307133417724, w0=-0.7343737897574903, w1=0.8754360109354568
# Gradient Descent(127/999): loss=10.773728674313492, w0=-0.7400725289647629, w1=0.876008511102017
# Gradient Descent(128/999): loss=10.767173910439322, w0=-0.7457609956485538, w1=0.8765799792821695
# Gradient Descent(129/999): loss=10.760642756446355, w0=-0.7514392083260708, w1=0.8771504173361683
# Gradient Descent(130/999): loss=10.754135127293164, w0=-0.7571071854811429, w1=0.8777198271209147
# Gradient Descent(131/999): loss=10.74765093824463, w0=-0.7627649455642799, w1=0.8782882104899624
# Gradient Descent(132/999): loss=10.74119010487086, w0=-0.7684125069927331, w1=0.8788555692935243
# Gradient Descent(133/999): loss=10.734752543046046, w0=-0.7740498881505549, w1=0.8794219053784776
# Gradient Descent(134/999): loss=10.728338168947424, w0=-0.7796771073886584, w1=0.8799872205883708
# Gradient Descent(135/999): loss=10.721946899054135, w0=-0.7852941830248777, w1=0.8805515167634289
# Gradient Descent(136/999): loss=10.715578650146169, w0=-0.7909011333440273, w1=0.8811147957405598
# Gradient Descent(137/999): loss=10.709233339303264, w0=-0.7964979765979614, w1=0.8816770593533604
# Gradient Descent(138/999): loss=10.702910883903835, w0=-0.8020847310056334, w1=0.882238309432122
# Gradient Descent(139/999): loss=10.696611201623886, w0=-0.8076614147531554, w1=0.8827985478038369
# Gradient Descent(140/999): loss=10.69033421043596, w0=-0.8132280459938575, w1=0.8833577762922041
# Gradient Descent(141/999): loss=10.68407982860806, w0=-0.8187846428483462, w1=0.883915996717635
# Gradient Descent(142/999): loss=10.677847974702567, w0=-0.8243312234045643, w1=0.8844732108972596
# Gradient Descent(143/999): loss=10.671638567575203, w0=-0.8298678057178493, w1=0.8850294206449325
# Gradient Descent(144/999): loss=10.665451526373976, w0=-0.8353944078109922, w1=0.8855846277712385
# Gradient Descent(145/999): loss=10.659286770538106, w0=-0.8409110476742958, w1=0.8861388340834986
# Gradient Descent(146/999): loss=10.653144219796998, w0=-0.8464177432656342, w1=0.8866920413857761
# Gradient Descent(147/999): loss=10.647023794169177, w0=-0.8519145125105105, w1=0.8872442514788821
# Gradient Descent(148/999): loss=10.64092541396126, w0=-0.8574013733021153, w1=0.8877954661603819
# Gradient Descent(149/999): loss=10.634848999766922, w0=-0.862878343501385, w1=0.8883456872246002
# Gradient Descent(150/999): loss=10.628794472465849, w0=-0.8683454409370602, w1=0.8888949164626272
# Gradient Descent(151/999): loss=10.622761753222708, w0=-0.8738026834057432, w1=0.8894431556623249
# Gradient Descent(152/999): loss=10.616750763486145, w0=-0.8792500886719562, w1=0.8899904066083322
# Gradient Descent(153/999): loss=10.610761424987722, w0=-0.8846876744681994, w1=0.8905366710820709
# Gradient Descent(154/999): loss=10.60479365974093, w0=-0.8901154584950083, w1=0.891081950861752
# Gradient Descent(155/999): loss=10.598847390040163, w0=-0.8955334584210115, w1=0.8916262477223807
# Gradient Descent(156/999): loss=10.592922538459703, w0=-0.9009416918829883, w1=0.892169563435763
# Gradient Descent(157/999): loss=10.58701902785272, w0=-0.9063401764859259, w1=0.8927118997705107
# Gradient Descent(158/999): loss=10.581136781350258, w0=-0.9117289298030768, w1=0.8932532584920476
# Gradient Descent(159/999): loss=10.575275722360239, w0=-0.9171079693760162, w1=0.8937936413626153
# Gradient Descent(160/999): loss=10.569435774566463, w0=-0.9224773127146988, w1=0.8943330501412785
# Gradient Descent(161/999): loss=10.563616861927622, w0=-0.9278369772975159, w1=0.8948714865839313
# Gradient Descent(162/999): loss=10.557818908676303, w0=-0.9331869805713524, w1=0.8954089524433027
# Gradient Descent(163/999): loss=10.552041839318003, w0=-0.9385273399516436, w1=0.8959454494689617
# Gradient Descent(164/999): loss=10.54628557863014, w0=-0.9438580728224316, w1=0.8964809794073243
# Gradient Descent(165/999): loss=10.540550051661087, w0=-0.9491791965364222, w1=0.8970155440016577
# Gradient Descent(166/999): loss=10.534835183729186, w0=-0.9544907284150413, w1=0.8975491449920872
# Gradient Descent(167/999): loss=10.52914090042177, w0=-0.9597926857484913, w1=0.898081784115601
# Gradient Descent(168/999): loss=10.523467127594218, w0=-0.9650850857958073, w1=0.8986134631060566
# Gradient Descent(169/999): loss=10.517813791368967, w0=-0.9703679457849134, w1=0.8991441836941857
# Gradient Descent(170/999): loss=10.512180818134548, w0=-0.9756412829126785, w1=0.8996739476076003
# Gradient Descent(171/999): loss=10.506568134544644, w0=-0.9809051143449727, w1=0.9002027565707984
# Gradient Descent(172/999): loss=10.50097566751713, w0=-0.9861594572167232, w1=0.900730612305169
# Gradient Descent(173/999): loss=10.495403344233111, w0=-0.9914043286319691, w1=0.9012575165289988
# Gradient Descent(174/999): loss=10.48985109213599, w0=-0.9966397456639188, w1=0.9017834709574764
# Gradient Descent(175/999): loss=10.484318838930504, w0=-1.0018657253550038, w1=0.9023084773026989
# Gradient Descent(176/999): loss=10.478806512581805, w0=-1.0070822847169356, w1=0.9028325372736775
# Gradient Descent(177/999): loss=10.473314041314502, w0=-1.0122894407307599, w1=0.9033556525763423
# Gradient Descent(178/999): loss=10.467841353611739, w0=-1.0174872103469128, w1=0.9038778249135484
# Gradient Descent(179/999): loss=10.462388378214257, w0=-1.0226756104852754, w1=0.9043990559850815
# Gradient Descent(180/999): loss=10.456955044119473, w0=-1.0278546580352295, w1=0.9049193474876631
# Gradient Descent(181/999): loss=10.451541280580543, w0=-1.0330243698557116, w1=0.9054387011149563
# Gradient Descent(182/999): loss=10.446147017105458, w0=-1.0381847627752687, w1=0.9059571185575711
# Gradient Descent(183/999): loss=10.440772183456112, w0=-1.043335853592113, w1=0.9064746015030701
# Gradient Descent(184/999): loss=10.435416709647393, w0=-1.0484776590741753, w1=0.9069911516359741
# Gradient Descent(185/999): loss=10.430080525946273, w0=-1.053610195959162, w1=0.907506770637767
# Gradient Descent(186/999): loss=10.424763562870899, w0=-1.058733480954607, w1=0.9080214601869018
# Gradient Descent(187/999): loss=10.419465751189687, w0=-1.0638475307379278, w1=0.9085352219588061
# Gradient Descent(188/999): loss=10.414187021920418, w0=-1.0689523619564794, w1=0.9090480576258873
# Gradient Descent(189/999): loss=10.408927306329344, w0=-1.0740479912276077, w1=0.9095599688575379
# Gradient Descent(190/999): loss=10.4036865359303, w0=-1.079134435138705, w1=0.9100709573201414
# Gradient Descent(191/999): loss=10.398464642483791, w0=-1.084211710247263, w1=0.9105810246770776
# Gradient Descent(192/999): loss=10.393261557996126, w0=-1.0892798330809266, w1=0.9110901725887276
# Gradient Descent(193/999): loss=10.38807721471852, w0=-1.0943388201375484, w1=0.9115984027124796
# Gradient Descent(194/999): loss=10.382911545146214, w0=-1.099388687885242, w1=0.9121057167027342
# Gradient Descent(195/999): loss=10.377764482017605, w0=-1.1044294527624352, w1=0.91261211621091
# Gradient Descent(196/999): loss=10.372635958313353, w0=-1.1094611311779248, w1=0.9131176028854483
# Gradient Descent(197/999): loss=10.367525907255517, w0=-1.1144837395109284, w1=0.9136221783718195
# Gradient Descent(198/999): loss=10.362434262306698, w0=-1.119497294111139, w1=0.9141258443125273
# Gradient Descent(199/999): loss=10.357360957169151, w0=-1.1245018112987772, w1=0.9146286023471152
# Gradient Descent(200/999): loss=10.352305925783934, w0=-1.1294973073646455, w1=0.9151304541121706
# Gradient Descent(201/999): loss=10.347269102330044, w0=-1.1344837985701801, w1=0.9156314012413316
# Gradient Descent(202/999): loss=10.342250421223564, w0=-1.1394613011475045, w1=0.9161314453652908
# Gradient Descent(203/999): loss=10.337249817116806, w0=-1.1444298312994825, w1=0.9166305881118018
# Gradient Descent(204/999): loss=10.332267224897462, w0=-1.1493894051997706, w1=0.9171288311056836
# Gradient Descent(205/999): loss=10.327302579687752, w0=-1.1543400389928706, w1=0.9176261759688266
# Gradient Descent(206/999): loss=10.322355816843578, w0=-1.1592817487941822, w1=0.9181226243201975
# Gradient Descent(207/999): loss=10.3174268719537, w0=-1.1642145506900559, w1=0.9186181777758449
# Gradient Descent(208/999): loss=10.312515680838867, w0=-1.1691384607378448, w1=0.9191128379489037
# Gradient Descent(209/999): loss=10.30762217955101, w0=-1.1740534949659571, w1=0.9196066064496018
# Gradient Descent(210/999): loss=10.302746304372395, w0=-1.1789596693739082, w1=0.9200994848852637
# Gradient Descent(211/999): loss=10.29788799181479, w0=-1.183856999932373, w1=0.9205914748603171
# Gradient Descent(212/999): loss=10.293047178618645, w0=-1.1887455025832374, w1=0.9210825779762974
# Gradient Descent(213/999): loss=10.28822380175228, w0=-1.193625193239651, w1=0.921572795831853
# Gradient Descent(214/999): loss=10.28341779841103, w0=-1.1984960877860782, w1=0.9220621300227506
# Gradient Descent(215/999): loss=10.278629106016465, w0=-1.20335820207835, w1=0.9225505821418805
# Gradient Descent(216/999): loss=10.273857662215557, w0=-1.2082115519437158, w1=0.9230381537792616
# Gradient Descent(217/999): loss=10.269103404879866, w0=-1.2130561531808948, w1=0.9235248465220465
# Gradient Descent(218/999): loss=10.26436627210473, w0=-1.2178920215601279, w1=0.924010661954527
# Gradient Descent(219/999): loss=10.259646202208474, w0=-1.2227191728232283, w1=0.9244956016581389
# Gradient Descent(220/999): loss=10.254943133731597, w0=-1.227537622683633, w1=0.9249796672114676
# Gradient Descent(221/999): loss=10.25025700543596, w0=-1.232347386826454, w1=0.9254628601902526
# Gradient Descent(222/999): loss=10.245587756304015, w0=-1.2371484809085298, w1=0.9259451821673931
# Gradient Descent(223/999): loss=10.240935325537983, w0=-1.2419409205584755, w1=0.9264266347129532
# Gradient Descent(224/999): loss=10.236299652559085, w0=-1.2467247213767343, w1=0.9269072193941664
# Gradient Descent(225/999): loss=10.231680677006734, w0=-1.2514998989356283, w1=0.9273869377754416
# Gradient Descent(226/999): loss=10.227078338737767, w0=-1.2562664687794085, w1=0.9278657914183671
# Gradient Descent(227/999): loss=10.22249257782565, w0=-1.2610244464243063, w1=0.928343781881717
# Gradient Descent(228/999): loss=10.217923334559694, w0=-1.2657738473585838, w1=0.928820910721455
# Gradient Descent(229/999): loss=10.2133705494443, w0=-1.2705146870425834, w1=0.9292971794907403
# Gradient Descent(230/999): loss=10.208834163198153, w0=-1.2752469809087792, w1=0.9297725897399323
# Gradient Descent(231/999): loss=10.204314116753473, w0=-1.2799707443618265, w1=0.9302471430165956
# Gradient Descent(232/999): loss=10.199810351255238, w0=-1.2846859927786125, w1=0.9307208408655054
# Gradient Descent(233/999): loss=10.195322808060421, w0=-1.289392741508306, w1=0.9311936848286523
# Gradient Descent(234/999): loss=10.19085142873722, w0=-1.2940910058724073, w1=0.931665676445247
# Gradient Descent(235/999): loss=10.186396155064301, w0=-1.2987808011647985, w1=0.932136817251726
# Gradient Descent(236/999): loss=10.181956929030042, w0=-1.303462142651793, w1=0.932607108781756
# Gradient Descent(237/999): loss=10.177533692831776, w0=-1.3081350455721847, w1=0.9330765525662391
# Gradient Descent(238/999): loss=10.173126388875033, w0=-1.312799525137299, w1=0.9335451501333181
# Gradient Descent(239/999): loss=10.168734959772802, w0=-1.3174555965310406, w1=0.9340129030083807
# Gradient Descent(240/999): loss=10.164359348344773, w0=-1.3221032749099442, w1=0.9344798127140653
# Gradient Descent(241/999): loss=10.159999497616594, w0=-1.3267425754032232, w1=0.9349458807702655
# Gradient Descent(242/999): loss=10.155655350819135, w0=-1.331373513112819, w1=0.9354111086941351
# Gradient Descent(243/999): loss=10.151326851387743, w0=-1.335996103113451, w1=0.9358754980000933
# Gradient Descent(244/999): loss=10.14701394296151, w0=-1.3406103604526642, w1=0.9363390501998291
# Gradient Descent(245/999): loss=10.142716569382536, w0=-1.3452163001508792, w1=0.9368017668023066
# Gradient Descent(246/999): loss=10.138434674695192, w0=-1.349813937201441, w1=0.9372636493137702
# Gradient Descent(247/999): loss=10.13416820314541, w0=-1.3544032865706677, w1=0.9377246992377486
# Gradient Descent(248/999): loss=10.129917099179938, w0=-1.3589843631978988, w1=0.9381849180750605
# Gradient Descent(249/999): loss=10.12568130744562, w0=-1.3635571819955448, w1=0.9386443073238195
# Gradient Descent(250/999): loss=10.121460772788684, w0=-1.3681217578491345, w1=0.9391028684794384
# Gradient Descent(251/999): loss=10.11725544025402, w0=-1.3726781056173645, w1=0.9395606030346343
# Gradient Descent(252/999): loss=10.11306525508446, w0=-1.377226240132147, w1=0.9400175124794338
# Gradient Descent(253/999): loss=10.108890162720073, w0=-1.3817661761986584, w1=0.9404735983011773
# Gradient Descent(254/999): loss=10.104730108797437, w0=-1.3862979285953874, w1=0.9409288619845243
# Gradient Descent(255/999): loss=10.100585039148958, w0=-1.3908215120741827, w1=0.9413833050114583
# Gradient Descent(256/999): loss=10.096454899802147, w0=-1.3953369413603018, w1=0.9418369288612908
# Gradient Descent(257/999): loss=10.092339636978913, w0=-1.3998442311524586, w1=0.9422897350106672
# Gradient Descent(258/999): loss=10.088239197094884, w0=-1.4043433961228704, w1=0.9427417249335708
# Gradient Descent(259/999): loss=10.084153526758682, w0=-1.4088344509173072, w1=0.9431929001013282
# Gradient Descent(260/999): loss=10.080082572771254, w0=-1.4133174101551385, w1=0.9436432619826134
# Gradient Descent(261/999): loss=10.076026282125152, w0=-1.4177922884293805, w1=0.9440928120434534
# Gradient Descent(262/999): loss=10.071984602003877, w0=-1.4222591003067446, w1=0.9445415517472323
# Gradient Descent(263/999): loss=10.067957479781159, w0=-1.426717860327684, w1=0.9449894825546963
# Gradient Descent(264/999): loss=10.063944863020282, w0=-1.4311685830064413, w1=0.9454366059239585
# Gradient Descent(265/999): loss=10.059946699473414, w0=-1.435611282831096, w1=0.9458829233105036
# Gradient Descent(266/999): loss=10.05596293708091, w0=-1.4400459742636116, w1=0.9463284361671929
# Gradient Descent(267/999): loss=10.051993523970648, w0=-1.4444726717398821, w1=0.9467731459442682
# Gradient Descent(268/999): loss=10.048038408457334, w0=-1.4488913896697797, w1=0.9472170540893577
# Gradient Descent(269/999): loss=10.044097539041854, w0=-1.4533021424372015, w1=0.9476601620474799
# Gradient Descent(270/999): loss=10.040170864410586, w0=-1.4577049444001158, w1=0.9481024712610484
# Gradient Descent(271/999): loss=10.036258333434734, w0=-1.4620998098906097, w1=0.9485439831698768
# Gradient Descent(272/999): loss=10.032359895169668, w0=-1.4664867532149353, w1=0.9489846992111832
# Gradient Descent(273/999): loss=10.028475498854258, w0=-1.470865788653556, w1=0.9494246208195952
# Gradient Descent(274/999): loss=10.024605093910212, w0=-1.4752369304611939, w1=0.9498637494271542
# Gradient Descent(275/999): loss=10.020748629941417, w0=-1.479600192866875, w1=0.9503020864633203
# Gradient Descent(276/999): loss=10.016906056733283, w0=-1.4839555900739763, w1=0.9507396333549765
# Gradient Descent(277/999): loss=10.013077324252095, w0=-1.4883031362602719, w1=0.9511763915264342
# Gradient Descent(278/999): loss=10.009262382644351, w0=-1.4926428455779792, w1=0.9516123623994371
# Gradient Descent(279/999): loss=10.005461182236122, w0=-1.4969747321538047, w1=0.9520475473931662
# Gradient Descent(280/999): loss=10.0016736735324, w0=-1.5012988100889904, w1=0.9524819479242441
# Gradient Descent(281/999): loss=9.997899807216452, w0=-1.505615093459359, w1=0.9529155654067399
# Gradient Descent(282/999): loss=9.99413953414919, w0=-1.5099235963153608, w1=0.9533484012521737
# Gradient Descent(283/999): loss=9.990392805368513, w0=-1.514224332682118, w1=0.9537804568695212
# Gradient Descent(284/999): loss=9.986659572088685, w0=-1.518517316559472, w1=0.9542117336652183
# Gradient Descent(285/999): loss=9.98293978569969, w0=-1.522802561922028, w1=0.9546422330431656
# Gradient Descent(286/999): loss=9.9792333977666, w0=-1.5270800827192001, w1=0.9550719564047333
# Gradient Descent(287/999): loss=9.975540360028956, w0=-1.5313498928752576, w1=0.955500905148765
# Gradient Descent(288/999): loss=9.97186062440012, w0=-1.5356120062893701, w1=0.9559290806715831
# Gradient Descent(289/999): loss=9.968194142966667, w0=-1.5398664368356523, w1=0.956356484366993
# Gradient Descent(290/999): loss=9.964540867987743, w0=-1.5441131983632097, w1=0.9567831176262876
# Gradient Descent(291/999): loss=9.960900751894469, w0=-1.5483523046961836, w1=0.9572089818382518
# Gradient Descent(292/999): loss=9.957273747289296, w0=-1.5525837696337954, w1=0.957634078389167
# Gradient Descent(293/999): loss=9.953659806945396, w0=-1.5568076069503929, w1=0.9580584086628159
# Gradient Descent(294/999): loss=9.950058883806062, w0=-1.5610238303954935, w1=0.9584819740404867
# Gradient Descent(295/999): loss=9.94647093098407, w0=-1.5652324536938302, w1=0.9589047759009777
# Gradient Descent(296/999): loss=9.942895901761082, w0=-1.569433490545396, w1=0.9593268156206016
# Gradient Descent(297/999): loss=9.939333749587044, w0=-1.573626954625488, w1=0.9597480945731905
# Gradient Descent(298/999): loss=9.935784428079568, w0=-1.5778128595847523, w1=0.9601686141300999
# Gradient Descent(299/999): loss=9.932247891023335, w0=-1.5819912190492287, w1=0.9605883756602133
# Gradient Descent(300/999): loss=9.928724092369489, w0=-1.5861620466203945, w1=0.9610073805299465
# Gradient Descent(301/999): loss=9.925212986235039, w0=-1.5903253558752093, w1=0.9614256301032524
# Gradient Descent(302/999): loss=9.92171452690226, w0=-1.5944811603661584, w1=0.9618431257416252
# Gradient Descent(303/999): loss=9.918228668818106, w0=-1.598629473621298, w1=0.9622598688041049
# Gradient Descent(304/999): loss=9.914755366593608, w0=-1.6027703091442984, w1=0.9626758606472816
# Gradient Descent(305/999): loss=9.911294575003279, w0=-1.6069036804144885, w1=0.9630911026253001
# Gradient Descent(306/999): loss=9.90784624898454, w0=-1.611029600886899, w1=0.9635055960898642
# Gradient Descent(307/999): loss=9.904410343637121, w0=-1.6151480839923067, w1=0.9639193423902411
# Gradient Descent(308/999): loss=9.90098681422248, w0=-1.6192591431372787, w1=0.9643323428732659
# Gradient Descent(309/999): loss=9.897575616163222, w0=-1.6233627917042148, w1=0.9647445988833457
# Gradient Descent(310/999): loss=9.894176705042515, w0=-1.627459043051392, w1=0.9651561117624645
# Gradient Descent(311/999): loss=9.89079003660352, w0=-1.6315479105130077, w1=0.965566882850187
# Gradient Descent(312/999): loss=9.887415566748798, w0=-1.6356294073992232, w1=0.9659769134836632
# Gradient Descent(313/999): loss=9.884053251539756, w0=-1.6397035469962071, w1=0.966386204997633
# Gradient Descent(314/999): loss=9.880703047196057, w0=-1.643770342566178, w1=0.9667947587244299
# Gradient Descent(315/999): loss=9.877364910095073, w0=-1.6478298073474484, w1=0.9672025759939861
# Gradient Descent(316/999): loss=9.874038796771282, w0=-1.6518819545544674, w1=0.9676096581338364
# Gradient Descent(317/999): loss=9.870724663915738, w0=-1.6559267973778635, w1=0.9680160064691224
# Gradient Descent(318/999): loss=9.867422468375484, w0=-1.6599643489844884, w1=0.9684216223225973
# Gradient Descent(319/999): loss=9.864132167152999, w0=-1.6639946225174589, w1=0.9688265070146297
# Gradient Descent(320/999): loss=9.860853717405638, w0=-1.6680176310962, w1=0.969230661863208
# Gradient Descent(321/999): loss=9.85758707644507, w0=-1.6720333878164881, w1=0.9696340881839453
# Gradient Descent(322/999): loss=9.854332201736726, w0=-1.676041905750493, w1=0.9700367872900825
# Gradient Descent(323/999): loss=9.851089050899247, w0=-1.6800431979468202, w1=0.9704387604924937
# Gradient Descent(324/999): loss=9.847857581703924, w0=-1.6840372774305545, w1=0.9708400090996899
# Gradient Descent(325/999): loss=9.844637752074158, w0=-1.6880241572033017, w1=0.9712405344178237
# Gradient Descent(326/999): loss=9.841429520084906, w0=-1.6920038502432304, w1=0.9716403377506925
# Gradient Descent(327/999): loss=9.838232843962134, w0=-1.695976369505115, w1=0.9720394203997442
# Gradient Descent(328/999): loss=9.83504768208228, w0=-1.6999417279203783, w1=0.9724377836640804
# Gradient Descent(329/999): loss=9.831873992971705, w0=-1.7038999383971323, w1=0.9728354288404608
# Gradient Descent(330/999): loss=9.828711735306152, w0=-1.707851013820221, w1=0.973232357223308
# Gradient Descent(331/999): loss=9.825560867910223, w0=-1.7117949670512624, w1=0.9736285701047109
# Gradient Descent(332/999): loss=9.82242134975682, w0=-1.71573181092869, w1=0.9740240687744296
# Gradient Descent(333/999): loss=9.819293139966625, w0=-1.7196615582677952, w1=0.9744188545198987
# Gradient Descent(334/999): loss=9.816176197807568, w0=-1.723584221860768, w1=0.9748129286262328
# Gradient Descent(335/999): loss=9.813070482694295, w0=-1.7274998144767397, w1=0.9752062923762296
# Gradient Descent(336/999): loss=9.80997595418763, w0=-1.731408348861824, w1=0.9755989470503743
# Gradient Descent(337/999): loss=9.806892571994066, w0=-1.7353098377391583, w1=0.9759908939268442
# Gradient Descent(338/999): loss=9.803820295965219, w0=-1.7392042938089454, w1=0.9763821342815124
# Gradient Descent(339/999): loss=9.800759086097335, w0=-1.743091729748495, w1=0.9767726693879522
# Gradient Descent(340/999): loss=9.797708902530733, w0=-1.7469721582122641, w1=0.977162500517441
# Gradient Descent(341/999): loss=9.794669705549312, w0=-1.7508455918318997, w1=0.9775516289389647
# Gradient Descent(342/999): loss=9.791641455580034, w0=-1.7547120432162784, w1=0.977940055919222
# Gradient Descent(343/999): loss=9.788624113192384, w0=-1.7585715249515483, w1=0.9783277827226277
# Gradient Descent(344/999): loss=9.785617639097886, w0=-1.7624240496011698, w1=0.9787148106113177
# Gradient Descent(345/999): loss=9.78262199414958, w0=-1.7662696297059566, w1=0.9791011408451529
# Gradient Descent(346/999): loss=9.779637139341498, w0=-1.770108277784116, w1=0.979486774681723
# Gradient Descent(347/999): loss=9.776663035808182, w0=-1.77394000633129, w1=0.9798717133763507
# Gradient Descent(348/999): loss=9.77369964482416, w0=-1.7777648278205966, w1=0.980255958182096
# Gradient Descent(349/999): loss=9.770746927803449, w0=-1.7815827547026695, w1=0.98063951034976
# Gradient Descent(350/999): loss=9.767804846299047, w0=-1.7853937994056985, w1=0.9810223711278895
# Gradient Descent(351/999): loss=9.76487336200244, w0=-1.7891979743354711, w1=0.98140454176278
# Gradient Descent(352/999): loss=9.761952436743094, w0=-1.7929952918754117, w1=0.9817860234984812
# Gradient Descent(353/999): loss=9.75904203248797, w0=-1.7967857643866227, w1=0.9821668175767997
# Gradient Descent(354/999): loss=9.756142111341019, w0=-1.8005694042079243, w1=0.9825469252373038
# Gradient Descent(355/999): loss=9.753252635542681, w0=-1.8043462236558947, w1=0.9829263477173273
# Gradient Descent(356/999): loss=9.750373567469426, w0=-1.8081162350249103, w1=0.983305086251974
# Gradient Descent(357/999): loss=9.74750486963322, w0=-1.8118794505871858, w1=0.9836831420741207
# Gradient Descent(358/999): loss=9.74464650468107, w0=-1.815635882592814, w1=0.9840605164144222
# Gradient Descent(359/999): loss=9.741798435394523, w0=-1.819385543269806, w1=0.9844372105013148
# Gradient Descent(360/999): loss=9.738960624689188, w0=-1.8231284448241303, w1=0.9848132255610205
# Gradient Descent(361/999): loss=9.736133035614245, w0=-1.8268645994397532, w1=0.9851885628175507
# Gradient Descent(362/999): loss=9.733315631351973, w0=-1.8305940192786783, w1=0.9855632234927107
# Gradient Descent(363/999): loss=9.730508375217266, w0=-1.8343167164809857, w1=0.9859372088061034
# Gradient Descent(364/999): loss=9.727711230657146, w0=-1.8380327031648724, w1=0.9863105199751329
# Gradient Descent(365/999): loss=9.724924161250318, w0=-1.8417419914266906, w1=0.986683158215009
# Gradient Descent(366/999): loss=9.722147130706649, w0=-1.845444593340988, w1=0.987055124738751
# Gradient Descent(367/999): loss=9.71938010286674, w0=-1.8491405209605467, w1=0.9874264207571918
# Gradient Descent(368/999): loss=9.71662304170143, w0=-1.8528297863164227, w1=0.9877970474789811
# Gradient Descent(369/999): loss=9.713875911311328, w0=-1.8565124014179843, w1=0.9881670061105906
# Gradient Descent(370/999): loss=9.711138675926357, w0=-1.8601883782529525, w1=0.9885362978563167
# Gradient Descent(371/999): loss=9.70841129990528, w0=-1.8638577287874387, w1=0.988904923918285
# Gradient Descent(372/999): loss=9.705693747735236, w0=-1.8675204649659847, w1=0.9892728854964544
# Gradient Descent(373/999): loss=9.70298598403128, w0=-1.8711765987116007, w1=0.9896401837886206
# Gradient Descent(374/999): loss=9.700287973535923, w0=-1.8748261419258045, w1=0.9900068199904203
# Gradient Descent(375/999): loss=9.697599681118671, w0=-1.878469106488661, w1=0.9903727952953345
# Gradient Descent(376/999): loss=9.694921071775568, w0=-1.882105504258819, w1=0.9907381108946934
# Gradient Descent(377/999): loss=9.69225211062874, w0=-1.885735347073552, w1=0.9911027679776795
# Gradient Descent(378/999): loss=9.689592762925935, w0=-1.8893586467487953, w1=0.9914667677313316
# Gradient Descent(379/999): loss=9.686942994040091, w0=-1.8929754150791847, w1=0.9918301113405488
# Gradient Descent(380/999): loss=9.684302769468857, w0=-1.896585663838095, w1=0.9921927999880943
# Gradient Descent(381/999): loss=9.681672054834163, w0=-1.9001894047776786, w1=0.9925548348545994
# Gradient Descent(382/999): loss=9.679050815881768, w0=-1.9037866496289035, w1=0.9929162171185668
# Gradient Descent(383/999): loss=9.676439018480808, w0=-1.9073774101015915, w1=0.9932769479563754
# Gradient Descent(384/999): loss=9.673836628623365, w0=-1.910961697884456, w1=0.9936370285422832
# Gradient Descent(385/999): loss=9.671243612424007, w0=-1.9145395246451407, w1=0.9939964600484313
# Gradient Descent(386/999): loss=9.668659936119356, w0=-1.9181109020302571, w1=0.9943552436448486
# Gradient Descent(387/999): loss=9.666085566067652, w0=-1.921675841665423, w1=0.9947133804994541
# Gradient Descent(388/999): loss=9.663520468748313, w0=-1.9252343551552993, w1=0.9950708717780621
# Gradient Descent(389/999): loss=9.660964610761487, w0=-1.9287864540836286, w1=0.9954277186443851
# Gradient Descent(390/999): loss=9.658417958827634, w0=-1.9323321500132729, w1=0.995783922260038
# Gradient Descent(391/999): loss=9.655880479787081, w0=-1.9358714544862508, w1=0.9961394837845419
# Gradient Descent(392/999): loss=9.653352140599596, w0=-1.9394043790237754, w1=0.9964944043753273
# Gradient Descent(393/999): loss=9.650832908343958, w0=-1.9429309351262916, w1=0.9968486851877391
# Gradient Descent(394/999): loss=9.648322750217522, w0=-1.9464511342735138, w1=0.9972023273750387
# Gradient Descent(395/999): loss=9.645821633535798, w0=-1.9499649879244632, w1=0.9975553320884093
# Gradient Descent(396/999): loss=9.643329525732023, w0=-1.9534725075175046, w1=0.9979077004769586
# Gradient Descent(397/999): loss=9.640846394356739, w0=-1.9569737044703845, w1=0.9982594336877233
# Gradient Descent(398/999): loss=9.638372207077376, w0=-1.9604685901802676, w1=0.998610532865672
# Gradient Descent(399/999): loss=9.635906931677804, w0=-1.9639571760237742, w1=0.9989609991537096
# Gradient Descent(400/999): loss=9.633450536057955, w0=-1.9674394733570169, w1=0.9993108336926809
# Gradient Descent(401/999): loss=9.631002988233371, w0=-1.970915493515638, w1=0.9996600376213742
# Gradient Descent(402/999): loss=9.628564256334808, w0=-1.9743852478148467, w1=1.0000086120765248
# Gradient Descent(403/999): loss=9.626134308607803, w0=-1.9778487475494546, w1=1.000356558192819
# Gradient Descent(404/999): loss=9.623713113412283, w0=-1.9813060039939139, w1=1.0007038771028982
# Gradient Descent(405/999): loss=9.621300639222133, w0=-1.984757028402353, w1=1.0010505699373613
# Gradient Descent(406/999): loss=9.618896854624792, w0=-1.9882018320086143, w1=1.0013966378247696
# Gradient Descent(407/999): loss=9.61650172832085, w0=-1.9916404260262899, w1=1.0017420818916503
# Gradient Descent(408/999): loss=9.614115229123636, w0=-1.9950728216487579, w1=1.0020869032624995
# Gradient Descent(409/999): loss=9.611737325958806, w0=-1.9984990300492198, w1=1.0024311030597866
# Gradient Descent(410/999): loss=9.60936798786395, w0=-2.001919062380736, w1=1.0027746824039572
# Gradient Descent(411/999): loss=9.60700718398818, w0=-2.0053329297762628, w1=1.0031176424134378
# Gradient Descent(412/999): loss=9.604654883591731, w0=-2.008740643348688, w1=1.0034599842046386
# Gradient Descent(413/999): loss=9.602311056045561, w0=-2.0121422141908676, w1=1.0038017088919569
# Gradient Descent(414/999): loss=9.599975670830954, w0=-2.015537653375661, w1=1.004142817587782
# Gradient Descent(415/999): loss=9.597648697539112, w0=-2.018926971955968, w1=1.0044833114024974
# Gradient Descent(416/999): loss=9.595330105870783, w0=-2.0223101809647654, w1=1.004823191444485
# Gradient Descent(417/999): loss=9.593019865635837, w0=-2.025687291415141, w1=1.0051624588201291
# Gradient Descent(418/999): loss=9.590717946752898, w0=-2.0290583143003307, w1=1.0055011146338197
# Gradient Descent(419/999): loss=9.588424319248935, w0=-2.0324232605937538, w1=1.005839159987956
# Gradient Descent(420/999): loss=9.586138953258873, w0=-2.0357821412490495, w1=1.0061765959829492
# Gradient Descent(421/999): loss=9.583861819025225, w0=-2.039134967200112, w1=1.006513423717228
# Gradient Descent(422/999): loss=9.581592886897674, w0=-2.042481749361125, w1=1.0068496442872403
# Gradient Descent(423/999): loss=9.579332127332707, w0=-2.0458224986266003, w1=1.0071852587874581
# Gradient Descent(424/999): loss=9.57707951089323, w0=-2.0491572258714092, w1=1.0075202683103803
# Gradient Descent(425/999): loss=9.57483500824817, w0=-2.0524859419508217, w1=1.0078546739465364
# Gradient Descent(426/999): loss=9.572598590172108, w0=-2.055808657700539, w1=1.0081884767844902
# Gradient Descent(427/999): loss=9.570370227544895, w0=-2.0591253839367307, w1=1.008521677910843
# Gradient Descent(428/999): loss=9.56814989135127, w0=-2.0624361314560686, w1=1.008854278410238
# Gradient Descent(429/999): loss=9.565937552680479, w0=-2.0657409110357627, w1=1.0091862793653623
# Gradient Descent(430/999): loss=9.563733182725908, w0=-2.069039733433596, w1=1.0095176818569525
# Gradient Descent(431/999): loss=9.561536752784702, w0=-2.07233260938796, w1=1.0098484869637963
# Gradient Descent(432/999): loss=9.55934823425739, w0=-2.075619549617888, w1=1.0101786957627366
# Gradient Descent(433/999): loss=9.557167598647517, w0=-2.078900564823093, w1=1.0105083093286757
# Gradient Descent(434/999): loss=9.554994817561267, w0=-2.082175665684, w1=1.0108373287345784
# Gradient Descent(435/999): loss=9.552829862707103, w0=-2.08544486286178, w1=1.0111657550514748
# Gradient Descent(436/999): loss=9.550672705895384, w0=-2.0887081669983885, w1=1.0114935893484647
# Gradient Descent(437/999): loss=9.548523319038013, w0=-2.091965588716597, w1=1.011820832692721
# Gradient Descent(438/999): loss=9.546381674148062, w0=-2.095217138620028, w1=1.0121474861494921
# Gradient Descent(439/999): loss=9.544247743339415, w0=-2.09846282729319, w1=1.0124735507821072
# Gradient Descent(440/999): loss=9.542121498826393, w0=-2.1017026653015125, w1=1.012799027651978
# Gradient Descent(441/999): loss=9.540002912923402, w0=-2.1049366631913795, w1=1.0131239178186033
# Gradient Descent(442/999): loss=9.537891958044572, w0=-2.108164831490164, w1=1.0134482223395718
# Gradient Descent(443/999): loss=9.535788606703395, w0=-2.111387180706263, w1=1.013771942270566
# Gradient Descent(444/999): loss=9.533692831512369, w0=-2.11460372132913, w1=1.014095078665365
# Gradient Descent(445/999): loss=9.53160460518263, w0=-2.117814463829311, w1=1.0144176325758494
# Gradient Descent(446/999): loss=9.529523900523627, w0=-2.121019418658478, w1=1.0147396050520026
# Gradient Descent(447/999): loss=9.527450690442725, w0=-2.1242185962494626, w1=1.0150609971419156
# Gradient Descent(448/999): loss=9.525384947944895, w0=-2.1274120070162903, w1=1.0153818098917904
# Gradient Descent(449/999): loss=9.523326646132327, w0=-2.1305996613542137, w1=1.0157020443459428
# Gradient Descent(450/999): loss=9.521275758204107, w0=-2.1337815696397477, w1=1.0160217015468063
# Gradient Descent(451/999): loss=9.519232257455851, w0=-2.1369577422307025, w1=1.0163407825349353
# Gradient Descent(452/999): loss=9.51719611727936, w0=-2.140128189466217, w1=1.0166592883490084
# Gradient Descent(453/999): loss=9.515167311162282, w0=-2.1432929216667933, w1=1.016977220025832
# Gradient Descent(454/999): loss=9.513145812687755, w0=-2.1464519491343292, w1=1.0172945786003436
# Gradient Descent(455/999): loss=9.511131595534076, w0=-2.149605282152153, w1=1.0176113651056147
# Gradient Descent(456/999): loss=9.509124633474345, w0=-2.1527529309850553, w1=1.0179275805728554
# Gradient Descent(457/999): loss=9.507124900376134, w0=-2.155894905879325, w1=1.018243226031416
# Gradient Descent(458/999): loss=9.505132370201139, w0=-2.159031217062779, w1=1.0185583025087923
# Gradient Descent(459/999): loss=9.503147017004848, w0=-2.1621618747448, w1=1.0188728110306269
# Gradient Descent(460/999): loss=9.501168814936198, w0=-2.165286889116365, w1=1.0191867526207143
# Gradient Descent(461/999): loss=9.499197738237239, w0=-2.1684062703500824, w1=1.0195001283010032
# Gradient Descent(462/999): loss=9.4972337612428, w0=-2.1715200286002228, w1=1.0198129390916004
# Gradient Descent(463/999): loss=9.495276858380155, w0=-2.174628174002753, w1=1.0201251860107734
# Gradient Descent(464/999): loss=9.493327004168691, w0=-2.1777307166753683, w1=1.0204368700749549
# Gradient Descent(465/999): loss=9.491384173219572, w0=-2.180827666717527, w1=1.0207479922987448
# Gradient Descent(466/999): loss=9.489448340235413, w0=-2.1839190342104806, w1=1.021058553694914
# Gradient Descent(467/999): loss=9.487519480009947, w0=-2.1870048292173094, w1=1.0213685552744083
# Gradient Descent(468/999): loss=9.485597567427702, w0=-2.1900850617829537, w1=1.0216779980463508
# Gradient Descent(469/999): loss=9.483682577463664, w0=-2.1931597419342466, w1=1.0219868830180456
# Gradient Descent(470/999): loss=9.481774485182967, w0=-2.1962288796799467, w1=1.0222952111949812
# Gradient Descent(471/999): loss=9.479873265740547, w0=-2.1992924850107713, w1=1.0226029835808335
# Gradient Descent(472/999): loss=9.477978894380842, w0=-2.2023505678994284, w1=1.0229102011774691
# Gradient Descent(473/999): loss=9.476091346437457, w0=-2.205403138300649, w1=1.023216864984949
# Gradient Descent(474/999): loss=9.47421059733283, w0=-2.2084502061512206, w1=1.0235229760015305
# Gradient Descent(475/999): loss=9.472336622577945, w0=-2.2114917813700172, w1=1.0238285352236731
# Gradient Descent(476/999): loss=9.47046939777198, w0=-2.2145278738580343, w1=1.0241335436460386
# Gradient Descent(477/999): loss=9.46860889860201, w0=-2.2175584934984194, w1=1.0244380022614963
# Gradient Descent(478/999): loss=9.466755100842683, w0=-2.220583650156505, w1=1.024741912061126
# Gradient Descent(479/999): loss=9.464907980355903, w0=-2.22360335367984, w1=1.025045274034221
# Gradient Descent(480/999): loss=9.463067513090524, w0=-2.226617613898222, w1=1.0253480891682911
# Gradient Descent(481/999): loss=9.46123367508202, w0=-2.22962644062373, w1=1.0256503584490657
# Gradient Descent(482/999): loss=9.459406442452195, w0=-2.2326298436507557, w1=1.025952082860498
# Gradient Descent(483/999): loss=9.457585791408853, w0=-2.2356278327560353, w1=1.026253263384767
# Gradient Descent(484/999): loss=9.455771698245503, w0=-2.238620417698681, w1=1.0265539010022815
# Gradient Descent(485/999): loss=9.453964139341037, w0=-2.2416076082202143, w1=1.0268539966916828
# Gradient Descent(486/999): loss=9.452163091159434, w0=-2.2445894140445963, w1=1.0271535514298484
# Gradient Descent(487/999): loss=9.450368530249442, w0=-2.247565844878259, w1=1.027452566191895
# Gradient Descent(488/999): loss=9.448580433244286, w0=-2.2505369104101387, w1=1.0277510419511808
# Gradient Descent(489/999): loss=9.446798776861355, w0=-2.2535026203117057, w1=1.0280489796793102
# Gradient Descent(490/999): loss=9.445023537901895, w0=-2.256462984236997, w1=1.0283463803461357
# Gradient Descent(491/999): loss=9.443254693250719, w0=-2.2594180118226475, w1=1.0286432449197622
# Gradient Descent(492/999): loss=9.441492219875899, w0=-2.26236771268792, w1=1.0289395743665486
# Gradient Descent(493/999): loss=9.439736094828465, w0=-2.2653120964347386, w1=1.0292353696511127
# Gradient Descent(494/999): loss=9.437986295242107, w0=-2.268251172647719, w1=1.0295306317363329
# ...
# Gradient Descent(834/999): loss=9.095868440512994, w0=-3.0144941837400427, w1=1.1044988365630446
# Gradient Descent(835/999): loss=9.095357232373193, w0=-3.01608278745305, w1=1.1046584290373123
# Gradient Descent(836/999): loss=9.094847865575609, w0=-3.017668527555642, w1=1.104817733830853
# Gradient Descent(837/999): loss=9.094340333487837, w0=-3.0192514092097515, w1=1.1049767514622382
# Gradient Descent(838/999): loss=9.093834629501355, w0=-3.0208314375680057, w1=1.1051354824491055
# Gradient Descent(839/999): loss=9.093330747031448, w0=-3.0224086177737437, w1=1.1052939273081595
# Gradient Descent(840/999): loss=9.09282867951712, w0=-3.0239829549610335, w1=1.1054520865551725
# Gradient Descent(841/999): loss=9.092328420421007, w0=-3.025554454254688, w1=1.1056099607049876
# Gradient Descent(842/999): loss=9.091829963229284, w0=-3.027123120770283, w1=1.10576755027152
# Gradient Descent(843/999): loss=9.091333301451602, w0=-3.028688959614172, w1=1.1059248557677583
# Gradient Descent(844/999): loss=9.09083842862098, w0=-3.030251975883504, w1=1.1060818777057666
# Gradient Descent(845/999): loss=9.090345338293739, w0=-3.03181217466624, w1=1.1062386165966853
# Gradient Descent(846/999): loss=9.089854024049396, w0=-3.03336956104117, w1=1.1063950729507344
# Gradient Descent(847/999): loss=9.089364479490612, w0=-3.0349241400779285, w1=1.1065512472772134
# Gradient Descent(848/999): loss=9.088876698243075, w0=-3.0364759168370115, w1=1.106707140084504
# Gradient Descent(849/999): loss=9.088390673955443, w0=-3.0380248963697927, w1=1.1068627518800718
# Gradient Descent(850/999): loss=9.087906400299246, w0=-3.039571083718541, w1=1.107018083170467
# Gradient Descent(851/999): loss=9.087423870968815, w0=-3.0411144839164352, w1=1.1071731344613274
# Gradient Descent(852/999): loss=9.086943079681182, w0=-3.0426551019875823, w1=1.1073279062573786
# Gradient Descent(853/999): loss=9.086464020176024, w0=-3.0441929429470322, w1=1.1074823990624372
# Gradient Descent(854/999): loss=9.085986686215556, w0=-3.0457280118007946, w1=1.1076366133794109
# Gradient Descent(855/999): loss=9.085511071584467, w0=-3.047260313545856, w1=1.107790549710301
# Gradient Descent(856/999): loss=9.085037170089834, w0=-3.0487898531701947, w1=1.1079442085562046
# Gradient Descent(857/999): loss=9.084564975561033, w0=-3.050316635652798, w1=1.1080975904173147
# Gradient Descent(858/999): loss=9.084094481849677, w0=-3.0518406659636783, w1=1.1082506957929228
# Gradient Descent(859/999): loss=9.083625682829515, w0=-3.0533619490638886, w1=1.1084035251814204
# Gradient Descent(860/999): loss=9.083158572396371, w0=-3.0548804899055395, w1=1.108556079080301
# Gradient Descent(861/999): loss=9.082693144468054, w0=-3.0563962934318147, w1=1.1087083579861612
# Gradient Descent(862/999): loss=9.08222939298427, w0=-3.0579093645769873, w1=1.108860362394702
# Gradient Descent(863/999): loss=9.081767311906573, w0=-3.0594197082664363, w1=1.109012092800731
# Gradient Descent(864/999): loss=9.081306895218248, w0=-3.060927329416662, w1=1.109163549698164
# Gradient Descent(865/999): loss=9.080848136924265, w0=-3.062432232935302, w1=1.1093147335800266
# Gradient Descent(866/999): loss=9.080391031051182, w0=-3.063934423721148, w1=1.1094656449384557
# Gradient Descent(867/999): loss=9.079935571647075, w0=-3.0654339066641607, w1=1.1096162842647006
# Gradient Descent(868/999): loss=9.07948175278146, w0=-3.0669306866454864, w1=1.1097666520491256
# Gradient Descent(869/999): loss=9.079029568545206, w0=-3.068424768537472, w1=1.1099167487812107
# Gradient Descent(870/999): loss=9.078579013050478, w0=-3.0699161572036826, w1=1.1100665749495537
# Gradient Descent(871/999): loss=9.07813008043064, w0=-3.0714048574989157, w1=1.1102161310418717
# Gradient Descent(872/999): loss=9.07768276484019, w0=-3.072890874269217, w1=1.1103654175450026
# Gradient Descent(873/999): loss=9.077237060454685, w0=-3.074374212351898, w1=1.110514434944907
# Gradient Descent(874/999): loss=9.076792961470654, w0=-3.0758548765755496, w1=1.1106631837266687
# Gradient Descent(875/999): loss=9.076350462105534, w0=-3.077332871760059, w1=1.1108116643744983
# Gradient Descent(876/999): loss=9.075909556597592, w0=-3.078808202716625, w1=1.1109598773717324
# Gradient Descent(877/999): loss=9.075470239205846, w0=-3.0802808742477734, w1=1.1111078232008371
# Gradient Descent(878/999): loss=9.07503250420999, w0=-3.0817508911473737, w1=1.1112555023434083
# Gradient Descent(879/999): loss=9.07459634591033, w0=-3.0832182582006533, w1=1.1114029152801743
# Gradient Descent(880/999): loss=9.074161758627696, w0=-3.0846829801842146, w1=1.1115500624909966
# Gradient Descent(881/999): loss=9.073728736703373, w0=-3.086145061866049, w1=1.1116969444548714
# Gradient Descent(882/999): loss=9.073297274499032, w0=-3.087604508005553, w1=1.111843561649932
# Gradient Descent(883/999): loss=9.072867366396652, w0=-3.089061323353545, w1=1.1119899145534495
# Gradient Descent(884/999): loss=9.072439006798447, w0=-3.090515512652278, w1=1.1121360036418346
# Gradient Descent(885/999): loss=9.072012190126793, w0=-3.0919670806354578, w1=1.1122818293906394
# Gradient Descent(886/999): loss=9.071586910824163, w0=-3.093416032028257, w1=1.112427392274559
# Gradient Descent(887/999): loss=9.071163163353033, w0=-3.09486237154733, w1=1.112572692767432
# Gradient Descent(888/999): loss=9.070740942195846, w0=-3.0963061039008295, w1=1.1127177313422438
# Gradient Descent(889/999): loss=9.0703202418549, w0=-3.0977472337884215, w1=1.1128625084711268
# Gradient Descent(890/999): loss=9.0699010568523, w0=-3.0991857659013005, w1=1.113007024625362
# Gradient Descent(891/999): loss=9.069483381729892, w0=-3.100621704922204, w1=1.1131512802753818
# Gradient Descent(892/999): loss=9.06906721104917, w0=-3.1020550555254287, w1=1.1132952758907695
# Gradient Descent(893/999): loss=9.068652539391223, w0=-3.1034858223768453, w1=1.1134390119402626
# Gradient Descent(894/999): loss=9.068239361356657, w0=-3.1049140101339145, w1=1.1135824888917536
# Gradient Descent(895/999): loss=9.067827671565526, w0=-3.1063396234457006, w1=1.1137257072122912
# Gradient Descent(896/999): loss=9.06741746465727, w0=-3.107762666952888, w1=1.1138686673680829
# Gradient Descent(897/999): loss=9.067008735290623, w0=-3.1091831452877963, w1=1.1140113698244951
# Gradient Descent(898/999): loss=9.066601478143562, w0=-3.1106010630743937, w1=1.1141538150460557
# Gradient Descent(899/999): loss=9.066195687913249, w0=-3.112016424928314, w1=1.114296003496455
# Gradient Descent(900/999): loss=9.065791359315924, w0=-3.1134292354568704, w1=1.114437935638548
# Gradient Descent(901/999): loss=9.065388487086874, w0=-3.114839499259072, w1=1.1145796119343547
# Gradient Descent(902/999): loss=9.064987065980343, w0=-3.116247220925637, w1=1.1147210328450625
# Gradient Descent(903/999): loss=9.064587090769473, w0=-3.117652405039008, w1=1.1148621988310277
# Gradient Descent(904/999): loss=9.06418855624623, w0=-3.1190550561733685, w1=1.1150031103517763
# Gradient Descent(905/999): loss=9.06379145722134, w0=-3.1204551788946553, w1=1.1151437678660066
# Gradient Descent(906/999): loss=9.063395788524222, w0=-3.121852777760575, w1=1.1152841718315896
# Gradient Descent(907/999): loss=9.063001545002917, w0=-3.1232478573206195, w1=1.1154243227055707
# Gradient Descent(908/999): loss=9.062608721524027, w0=-3.1246404221160784, w1=1.115564220944172
# Gradient Descent(909/999): loss=9.062217312972637, w0=-3.1260304766800564, w1=1.1157038670027932
# Gradient Descent(910/999): loss=9.061827314252259, w0=-3.127418025537486, w1=1.1158432613360125
# Gradient Descent(911/999): loss=9.061438720284766, w0=-3.1288030732051433, w1=1.1159824043975894
# Gradient Descent(912/999): loss=9.06105152601032, w0=-3.1301856241916624, w1=1.116121296640465
# Gradient Descent(913/999): loss=9.060665726387304, w0=-3.1315656829975507, w1=1.1162599385167638
# Gradient Descent(914/999): loss=9.060281316392269, w0=-3.1329432541152022, w1=1.1163983304777958
# Gradient Descent(915/999): loss=9.05989829101985, w0=-3.1343183420289136, w1=1.116536472974057
# Gradient Descent(916/999): loss=9.05951664528272, w0=-3.135690951214898, w1=1.1166743664552319
# Gradient Descent(917/999): loss=9.059136374211509, w0=-3.137061086141299, w1=1.1168120113701936
# Gradient Descent(918/999): loss=9.05875747285475, w0=-3.1384287512682074, w1=1.116949408167007
# Gradient Descent(919/999): loss=9.058379936278813, w0=-3.1397939510476727, w1=1.1170865572929285
# Gradient Descent(920/999): loss=9.058003759567837, w0=-3.1411566899237204, w1=1.1172234591944088
# Gradient Descent(921/999): loss=9.057628937823667, w0=-3.1425169723323645, w1=1.1173601143170935
# Gradient Descent(922/999): loss=9.057255466165785, w0=-3.1438748027016232, w1=1.117496523105825
# Gradient Descent(923/999): loss=9.056883339731263, w0=-3.145230185451532, w1=1.117632686004644
# Gradient Descent(924/999): loss=9.056512553674683, w0=-3.1465831249941596, w1=1.1177686034567906
# Gradient Descent(925/999): loss=9.05614310316808, w0=-3.1479336257336215, w1=1.117904275904706
# Gradient Descent(926/999): loss=9.055774983400884, w0=-3.1492816920660935, w1=1.1180397037900336
# Gradient Descent(927/999): loss=9.055408189579843, w0=-3.150627328379828, w1=1.118174887553621
# Gradient Descent(928/999): loss=9.055042716928979, w0=-3.151970539055166, w1=1.118309827635521
# Gradient Descent(929/999): loss=9.054678560689515, w0=-3.1533113284645538, w1=1.1184445244749934
# Gradient Descent(930/999): loss=9.054315716119806, w0=-3.1546497009725547, w1=1.1185789785105058
# Gradient Descent(931/999): loss=9.0539541784953, w0=-3.1559856609358654, w1=1.1187131901797356
# Gradient Descent(932/999): loss=9.053593943108453, w0=-3.157319212703329, w1=1.1188471599195713
# Gradient Descent(933/999): loss=9.05323500526868, w0=-3.158650360615949, w1=1.1189808881661139
# Gradient Descent(934/999): loss=9.052877360302292, w0=-3.159979109006904, w1=1.1191143753546777
# Gradient Descent(935/999): loss=9.052521003552437, w0=-3.161305462201562, w1=1.1192476219197935
# Gradient Descent(936/999): loss=9.052165930379024, w0=-3.1626294245174935, w1=1.119380628295208
# Gradient Descent(937/999): loss=9.051812136158695, w0=-3.163951000264487, w1=1.1195133949138856
# Gradient Descent(938/999): loss=9.05145961628473, w0=-3.1652701937445613, w1=1.1196459222080113
# Gradient Descent(939/999): loss=9.051108366167005, w0=-3.166587009251981, w1=1.1197782106089904
# Gradient Descent(940/999): loss=9.050758381231937, w0=-3.16790145107327, w1=1.1199102605474507
# Gradient Descent(941/999): loss=9.050409656922405, w0=-3.1692135234872243, w1=1.1200420724532436
# Gradient Descent(942/999): loss=9.050062188697712, w0=-3.170523230764928, w1=1.1201736467554462
# Gradient Descent(943/999): loss=9.049715972033514, w0=-3.1718305771697657, w1=1.1203049838823613
# Gradient Descent(944/999): loss=9.049371002421758, w0=-3.173135566957437, w1=1.1204360842615202
# Gradient Descent(945/999): loss=9.049027275370639, w0=-3.1744382043759702, w1=1.1205669483196834
# Gradient Descent(946/999): loss=9.04868478640452, w0=-3.1757384936657362, w1=1.1206975764828424
# Gradient Descent(947/999): loss=9.04834353106389, w0=-3.177036439059462, w1=1.1208279691762202
# Gradient Descent(948/999): loss=9.048003504905306, w0=-3.1783320447822447, w1=1.1209581268242739
# Gradient Descent(949/999): loss=9.047664703501322, w0=-3.1796253150515654, w1=1.121088049850695
# Gradient Descent(950/999): loss=9.047327122440445, w0=-3.180916254077303, w1=1.1212177386784115
# Gradient Descent(951/999): loss=9.046990757327064, w0=-3.1822048660617472, w1=1.1213471937295894
# Gradient Descent(952/999): loss=9.046655603781414, w0=-3.183491155199613, w1=1.1214764154256327
# Gradient Descent(953/999): loss=9.046321657439492, w0=-3.1847751256780534, w1=1.1216054041871868
# Gradient Descent(954/999): loss=9.045988913953023, w0=-3.186056781676675, w1=1.1217341604341382
# Gradient Descent(955/999): loss=9.045657368989389, w0=-3.187336127367549, w1=1.121862684585617
# Gradient Descent(956/999): loss=9.045327018231582, w0=-3.1886131669152267, w1=1.1219909770599974
# Gradient Descent(957/999): loss=9.044997857378139, w0=-3.1898879044767523, w1=1.1221190382748996
# Gradient Descent(958/999): loss=9.044669882143094, w0=-3.191160344201676, w1=1.122246868647191
# Gradient Descent(959/999): loss=9.04434308825592, w0=-3.192430490232069, w1=1.1223744685929873
# Gradient Descent(960/999): loss=9.044017471461467, w0=-3.193698346702535, w1=1.1225018385276546
# Gradient Descent(961/999): loss=9.043693027519916, w0=-3.194963917740225, w1=1.12262897886581
# Gradient Descent(962/999): loss=9.043369752206722, w0=-3.1962272074648514, w1=1.122755890021323
# Gradient Descent(963/999): loss=9.04304764131255, w0=-3.197488219988699, w1=1.1228825724073175
# Gradient Descent(964/999): loss=9.042726690643226, w0=-3.1987469594166407, w1=1.1230090264361723
# Gradient Descent(965/999): loss=9.042406896019695, w0=-3.200003429846149, w1=1.123135252519523
# Gradient Descent(966/999): loss=9.042088253277944, w0=-3.2012576353673117, w1=1.1232612510682636
# Gradient Descent(967/999): loss=9.041770758268958, w0=-3.2025095800628427, w1=1.1233870224925466
# Gradient Descent(968/999): loss=9.041454406858673, w0=-3.2037592680080973, w1=1.1235125672017856
# Gradient Descent(969/999): loss=9.04113919492791, w0=-3.2050067032710836, w1=1.1236378856046565
# Gradient Descent(970/999): loss=9.040825118372332, w0=-3.2062518899124774, w1=1.123762978109098
# Gradient Descent(971/999): loss=9.040512173102382, w0=-3.207494831985635, w1=1.1238878451223138
# Gradient Descent(972/999): loss=9.040200355043234, w0=-3.2087355335366055, w1=1.1240124870507733
# Gradient Descent(973/999): loss=9.03988966013474, w0=-3.2099739986041445, w1=1.1241369043002134
# Gradient Descent(974/999): loss=9.039580084331376, w0=-3.2112102312197277, w1=1.1242610972756395
# Gradient Descent(975/999): loss=9.039271623602195, w0=-3.212444235407564, w1=1.124385066381327
# Gradient Descent(976/999): loss=9.038964273930755, w0=-3.213676015184608, w1=1.1245088120208229
# Gradient Descent(977/999): loss=9.038658031315096, w0=-3.2149055745605732, w1=1.1246323345969458
# Gradient Descent(978/999): loss=9.038352891767666, w0=-3.216132917537945, w1=1.1247556345117893
# Gradient Descent(979/999): loss=9.038048851315274, w0=-3.2173580481119948, w1=1.1248787121667216
# Gradient Descent(980/999): loss=9.03774590599905, w0=-3.218580970270791, w1=1.1250015679623873
# Gradient Descent(981/999): loss=9.037444051874369, w0=-3.219801687995214, w1=1.1251242022987091
# Gradient Descent(982/999): loss=9.037143285010826, w0=-3.2210202052589683, w1=1.1252466155748888
# Gradient Descent(983/999): loss=9.03684360149217, w0=-3.2222365260285946, w1=1.1253688081894084
# Gradient Descent(984/999): loss=9.036544997416252, w0=-3.223450654263484, w1=1.1254907805400316
# Gradient Descent(985/999): loss=9.036247468894983, w0=-3.2246625939158906, w1=1.1256125330238054
# Gradient Descent(986/999): loss=9.035951012054278, w0=-3.2258723489309444, w1=1.1257340660370605
# Gradient Descent(987/999): loss=9.035655623034005, w0=-3.227079923246663, w1=1.1258553799754139
# Gradient Descent(988/999): loss=9.035361297987937, w0=-3.228285320793966, w1=1.1259764752337689
# Gradient Descent(989/999): loss=9.0350680330837, w0=-3.2294885454966877, w1=1.1260973522063173
# Gradient Descent(990/999): loss=9.034775824502722, w0=-3.230689601271588, w1=1.12621801128654
# Gradient Descent(991/999): loss=9.034484668440191, w0=-3.2318884920283675, w1=1.126338452867209
# Gradient Descent(992/999): loss=9.034194561104997, w0=-3.2330852216696786, w1=1.1264586773403877
# Gradient Descent(993/999): loss=9.03390549871968, w0=-3.234279794091139, w1=1.1265786850974338
# Gradient Descent(994/999): loss=9.03361747752039, w0=-3.2354722131813443, w1=1.1266984765289982
# Gradient Descent(995/999): loss=9.033330493756845, w0=-3.23666248282188, w1=1.1268180520250288
# Gradient Descent(996/999): loss=9.033044543692252, w0=-3.237850606887336, w1=1.12693741197477
# Gradient Descent(997/999): loss=9.032759623603289, w0=-3.2390365892453157, w1=1.1270565567667643
# Gradient Descent(998/999): loss=9.032475729780046, w0=-3.240220433756453, w1=1.1271754867888546
# Gradient Descent(999/999): loss=9.032192858525969, w0=-3.241402144274421, w1=1.127294202428184
# [-3.24140214  1.1272942 ]

# %% [markdown]
# Finally we can compute the cost (error) of the trained model using our fitted parameters.

# %%
print(computeCost(X, y, g))
# Out:
# 9.031911006157827

# %% [markdown]
# Now let's plot the linear model along with the data to visually see how well it fits.

# %%
x = np.linspace(data.Population.min(), data.Population.max(), 100)
f = g[0] + (g[1] * x)

fig, ax = plt.subplots(figsize=(12,8))
ax.plot(x, f, 'r', label='Prediction')
ax.scatter(data.Population, data.Profit, label='Traning Data')
ax.legend(loc=2)
ax.set_xlabel('Population')
ax.set_ylabel('Profit')
ax.set_title('Predicted Profit vs. Population Size')
plt.grid()
plt.show()

# %% [markdown]
# Looks pretty good!  Since the gradient decent function also outputs a vector with the cost at each training iteration, we can plot that as well.  Notice that the cost always decreases - this is an example of a convex optimization problem.

# %%
fig, ax = plt.subplots(figsize=(12,8))
ax.plot(np.arange(iters), cost, 'r')
ax.set_xlabel('Iterations')
ax.set_ylabel('Cost')
ax.set_title('Error vs. Training Epoch')
plt.grid()
plt.show()
